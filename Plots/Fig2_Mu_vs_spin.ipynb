# %% [markdown]
# # All these datasets are obtained using ULB_bounds.nb

# %%
# %load_ext autoreload
import sys
sys.path.append("..")
# %matplotlib inline
# %autoreload
import matplotlib
matplotlib.rc_file('matplotlibrc')
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /home/oem/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:280: MatplotlibDeprecationWarning:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   import matplotlib

# %%
a=[0.01, 0.015, 0.02, 0.025, 0.03, 0.035, 0.04, 0.045, 0.05, 0.055, 
0.06, 0.065, 0.07, 0.075, 0.08, 0.085, 0.09, 0.095, 0.1, 0.105, 0.11, 
0.115, 0.12, 0.125, 0.13, 0.135, 0.14, 0.145, 0.15, 0.155, 0.16, 
0.165, 0.17, 0.175, 0.18, 0.185, 0.19, 0.195, 0.2, 0.205, 0.21, 
0.215, 0.22, 0.225, 0.23, 0.235, 0.24, 0.245, 0.25, 0.255, 0.26, 
0.265, 0.27, 0.275, 0.28, 0.285, 0.29, 0.295, 0.3, 0.305, 0.31, 
0.315, 0.32, 0.325, 0.33, 0.335, 0.34, 0.345, 0.35, 0.355, 0.36, 
0.365, 0.37, 0.375, 0.38, 0.385, 0.39, 0.395, 0.4, 0.405, 0.41, 
0.415, 0.42, 0.425, 0.43, 0.435, 0.44, 0.445, 0.45, 0.455, 0.46, 
0.465, 0.47, 0.475, 0.48, 0.485, 0.49, 0.495, 0.5, 0.505, 0.51, 
0.515, 0.52, 0.525, 0.53, 0.535, 0.54, 0.545, 0.55, 0.555, 0.56, 
0.565, 0.57, 0.575, 0.58, 0.585, 0.59, 0.595, 0.6, 0.605, 0.61, 
0.615, 0.62, 0.625, 0.63, 0.635, 0.64, 0.645, 0.65, 0.655, 0.66, 
0.665, 0.67, 0.675, 0.68, 0.685, 0.69, 0.695, 0.7, 0.705, 0.71, 
0.715, 0.72, 0.725, 0.73, 0.735, 0.74, 0.745, 0.75, 0.755, 0.76, 
0.765, 0.77, 0.775, 0.78, 0.785, 0.79, 0.795, 0.8, 0.805, 0.81, 
0.815, 0.82, 0.825, 0.83, 0.835, 0.84, 0.845, 0.85, 0.855, 0.86, 
0.865, 0.87, 0.875, 0.88, 0.885, 0.89, 0.895, 0.9, 0.905, 0.91, 
0.915, 0.92, 0.925, 0.93, 0.935, 0.94, 0.945, 0.95, 0.955, 0.96, 
0.965, 0.97, 0.975, 0.98, 0.985, 0.99]

# %%
Up0=[
8.33541*10**-20, 1.25035*10**-19, 1.66721*10**-19, 2.08412*10**-19, 
2.50112*10**-19, 2.91821*10**-19, 3.33541*10**-19, 3.75274*10**-19, 
4.17021*10**-19, 4.58783*10**-19, 5.00563*10**-19, 5.42361*10**-19, 
5.8418*10**-19, 6.26021*10**-19, 6.67886*10**-19, 7.09776*10**-19, 
7.51693*10**-19, 7.93638*10**-19, 8.35614*10**-19, 8.77621*10**-19, 
9.19662*10**-19, 9.61738*10**-19, 1.00385*10**-18, 1.046*10**-18, 
1.08819*10**-18, 1.13043*10**-18, 1.1727*10**-18, 1.21502*10**-18, 
1.25739*10**-18, 1.29981*10**-18, 1.34228*10**-18, 1.3848*10**-18, 
1.42737*10**-18, 1.47*10**-18, 1.51269*10**-18, 1.55544*10**-18, 
1.59824*10**-18, 1.64112*10**-18, 1.68405*10**-18, 1.72705*10**-18, 
1.77013*10**-18, 1.81327*10**-18, 1.85649*10**-18, 1.89978*10**-18, 
1.94314*10**-18, 1.98659*10**-18, 2.03011*10**-18, 2.07372*10**-18, 
1.3008*10**-17, 1.32986*10**-17, 1.36255*10**-17, 1.40039*10**-17, 
1.44634*10**-17]

# %% [markdown]
# ## Spin 0 case

# %%
Low0=[2.64207*10**-18, 2.52568*10**-18, 2.44622*10**-18, 
2.3863*10**-18, 2.33844*10**-18, 2.29872*10**-18, 
2.26486*10**-18, 2.23541*10**-18, 2.20939*10**-18, 
2.18611*10**-18, 2.16507*10**-18, 2.14589*10**-18, 
2.12829*10**-18, 2.11203*10**-18, 2.09693*10**-18, 
2.08285*10**-18, 2.06966*10**-18, 2.05725*10**-18, 
2.04556*10**-18, 2.03449*10**-18, 2.024*10**-18, 2.01402*10**-18, 
2.00451*10**-18, 1.99543*10**-18, 1.98675*10**-18, 
1.97843*10**-18, 1.97044*10**-18, 1.96277*10**-18, 
1.95539*10**-18, 1.94827*10**-18, 1.9414*10**-18, 
1.93477*10**-18, 1.92835*10**-18, 1.92215*10**-18, 
1.91613*10**-18, 1.9103*10**-18, 1.90465*10**-18, 
1.89915*10**-18, 1.89381*10**-18, 1.88861*10**-18, 
1.88356*10**-18, 1.87863*10**-18, 1.87383*10**-18, 
1.86915*10**-18, 1.86459*10**-18, 1.86013*10**-18, 
1.85578*10**-18, 1.85152*10**-18, 1.84737*10**-18, 
1.8433*10**-18, 1.83932*10**-18, 1.83542*10**-18, 
1.83161*10**-18, 1.82787*10**-18, 1.82421*10**-18, 
1.82062*10**-18, 1.8171*10**-18, 1.81364*10**-18, 
1.81025*10**-18, 1.80692*10**-18, 1.80365*10**-18, 
1.80044*10**-18, 1.79729*10**-18, 1.79419*10**-18, 
1.79114*10**-18, 1.78814*10**-18, 1.78519*10**-18, 
1.78229*10**-18, 1.77944*10**-18, 1.77663*10**-18, 
1.77386*10**-18, 1.77114*10**-18, 1.76845*10**-18, 
1.76581*10**-18, 1.76321*10**-18, 1.76064*10**-18, 
1.75811*10**-18, 1.75562*10**-18, 1.75316*10**-18, 
1.75073*10**-18, 1.74834*10**-18, 1.74597*10**-18, 
1.74364*10**-18, 1.74135*10**-18, 1.73908*10**-18, 
1.73683*10**-18, 1.73462*10**-18, 1.73244*10**-18, 
1.73028*10**-18, 1.72815*10**-18, 1.72604*10**-18, 
1.72396*10**-18, 1.72191*10**-18, 1.71987*10**-18, 
1.71786*10**-18, 1.71588*10**-18, 1.71391*10**-18, 
1.71197*10**-18, 1.71005*10**-18, 1.70815*10**-18, 
1.70628*10**-18, 1.70442*10**-18, 1.70258*10**-18, 
1.70076*10**-18, 1.69896*10**-18, 1.69718*10**-18, 
1.69542*10**-18, 1.69367*10**-18, 1.69194*10**-18, 
1.69023*10**-18, 1.68854*10**-18, 1.68686*10**-18, 
1.6852*10**-18, 1.68355*10**-18, 1.68192*10**-18, 
1.68031*10**-18, 1.67871*10**-18, 1.67713*10**-18, 
1.67556*10**-18, 1.674*10**-18, 1.67246*10**-18, 1.67093*10**-18, 
1.66942*10**-18, 1.66792*10**-18, 1.66643*10**-18, 
1.66495*10**-18, 1.66349*10**-18, 1.66204*10**-18, 
1.6606*10**-18, 1.65917*10**-18, 1.65776*10**-18, 
1.65636*10**-18, 1.65496*10**-18, 1.65358*10**-18, 
1.65222*10**-18, 1.65086*10**-18, 1.64951*10**-18, 
1.10723*10**-18, 1.10255*10**-18, 1.09806*10**-18, 
1.09374*10**-18, 1.08958*10**-18, 1.08557*10**-18, 
1.08169*10**-18, 1.07795*10**-18, 1.07432*10**-18, 
1.07081*10**-18, 1.06741*10**-18, 1.0641*10**-18, 
1.06089*10**-18, 1.05778*10**-18, 1.05474*10**-18, 
1.05179*10**-18, 1.04891*10**-18, 1.0461*10**-18, 
1.04336*10**-18, 1.04069*10**-18, 1.03808*10**-18, 
1.03553*10**-18, 1.03304*10**-18, 1.0306*10**-18, 
1.02821*10**-18, 1.02587*10**-18, 1.02358*10**-18, 
1.02133*10**-18, 1.01913*10**-18, 1.01697*10**-18, 
1.01484*10**-18, 1.01276*10**-18, 1.01072*10**-18, 
1.00871*10**-18, 1.00673*10**-18, 1.00479*10**-18, 
1.00288*10**-18, 1.001*10**-18, 9.99153*10**-19, 9.97332*10**-19, 
9.95539*10**-19, 9.93773*10**-19, 9.92032*10**-19, 
9.90317*10**-19, 9.88626*10**-19, 9.86958*10**-19, 
9.85313*10**-19, 9.8369*10**-19, 9.82088*10**-19, 
9.80507*10**-19, 9.78945*10**-19, 9.77403*10**-19, 
9.7588*10**-19, 9.74375*10**-19, 9.72888*10**-19, 
9.71418*10**-19, 9.69964*10**-19, 9.68526*10**-19, 
9.67105*10**-19, 9.65698*10**-19, 9.64306*10**-19, 
9.62929*10**-19, 9.61565*10**-19, 9.60215*10**-19, 
9.58879*10**-19, 9.57555*10**-19, 9.56243*10**-19, 
9.54944*10**-19, 9.53656*10**-19, 9.52379*10**-19, 
9.51114*10**-19, 9.4986*10**-19, 9.48616*10**-19, 
9.47382*10**-19, 9.46158*10**-19, 9.44944*10**-19, 
9.43739*10**-19, 9.42543*10**-19, 9.41356*10**-19, 
9.40177*10**-19, 9.39007*10**-19, 9.37845*10**-19, 
9.36691*10**-19, 9.35544*10**-19, 9.34404*10**-19, 
9.33272*10**-19, 9.32147*10**-19, 9.31028*10**-19, 
9.29916*10**-19, 9.2881*10**-19, 9.2771*10**-19, 9.26617*10**-19, 
9.25528*10**-19, 9.24445*10**-19, 9.23368*10**-19, 
9.22295*10**-19, 9.21228*10**-19, 9.20165*10**-19, 
9.19106*10**-19, 9.18052*10**-19, 9.17002*10**-19, 
9.15956*10**-19, 9.14914*10**-19, 9.13875*10**-19, 
9.1284*10**-19, 9.11807*10**-19, 9.10778*10**-19, 
9.09752*10**-19, 9.08728*10**-19, 9.07707*10**-19, 
9.06688*10**-19, 9.05671*10**-19, 9.04656*10**-19, 
9.03642*10**-19, 9.0263*10**-19, 9.01619*10**-19, 9.0061*10**-19, 
8.99601*10**-19, 8.98593*10**-19, 8.97585*10**-19, 
8.96578*10**-19, 8.9557*10**-19, 8.94563*10**-19, 
8.93555*10**-19, 8.92546*10**-19, 8.91536*10**-19, 
8.90525*10**-19, 8.89512*10**-19, 8.88498*10**-19, 
8.87482*10**-19, 8.86463*10**-19, 8.85442*10**-19, 
8.84417*10**-19, 8.8339*10**-19, 8.82358*10**-19, 
8.81323*10**-19, 8.80283*10**-19, 8.79239*10**-19, 
8.78189*10**-19, 8.77133*10**-19, 8.76071*10**-19, 
8.75002*10**-19, 8.73925*10**-19, 8.72841*10**-19, 
8.71748*10**-19, 8.70646*10**-19, 8.69534*10**-19, 
8.6841*10**-19, 8.67275*10**-19, 8.66127*10**-19, 
8.64965*10**-19, 8.63788*10**-19, 8.62594*10**-19, 
8.61382*10**-19, 8.60151*10**-19, 8.58898*10**-19, 
8.57622*10**-19, 8.5632*10**-19, 8.54989*10**-19, 
8.53625*10**-19, 8.52226*10**-19, 8.50787*10**-19, 
8.49302*10**-19, 8.47764*10**-19, 8.46166*10**-19, 
8.44498*10**-19, 8.42745*10**-19, 8.40892*10**-19, 
8.38912*10**-19, 8.3677*10**-19, 8.34413*10**-19, 
8.31745*10**-19, 8.28581*10**-19]

# %%
import matplotlib as mpl
def FigSetup(xlab='',ylab='',title='',\
                 x_min = 0,x_max = 2,\
                 y_min = 1e-23,y_max = 1.0e7,\
                 lw=2.5,lfs=32,tfs=32,tickdir='out',\
                 Grid=False,Shape='Rectangular'):
    
    plt.rcParams['axes.linewidth'] = lw
    plt.rc('text', usetex=True)
    plt.rc('font', family='serif',size=tfs)
    fig = plt.figure(figsize=(13,12))


    ax = fig.add_subplot(111)

    ax.set_xlabel(xlab,fontsize=lfs)
    ax.set_ylabel(ylab,fontsize=lfs)

    ax.tick_params(which='major',direction=tickdir,width=2.5,labelsize=26,length=13,right=True,top=True,pad=10) ######
    ax.tick_params(which='minor',direction=tickdir,width=1,length=10)
    
    #locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=50)
    #locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10)*.1,numticks=50)
    #ax.xaxis.set_major_locator(locmaj)
    #ax.xaxis.set_minor_locator(locmin)
    ax.xaxis.set_minor_formatter(mpl.ticker.NullFormatter())


    locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
    locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10)*.1,numticks=100)
    ax.yaxis.set_major_locator(locmaj)
    ax.yaxis.set_minor_locator(locmin)
    #ax.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())

    ax.set_yscale('log')
    #ax.set_xscale('log')
    ax.set_xlim([x_min,x_max])
    ax.set_ylim([y_min,y_max])
    ax.set_title(title,fontsize=30) ########

    
    return fig,ax

# %%
a1=a[43:]
fig,ax = FigSetup(
                y_min=1e-19,y_max=2e-17,x_min=0.01,x_max=1,tickdir='in'
                 )

#plt.plot(a, Up0,label='UpperLimit')
#plt.plot(a, Low0,label='Spin-0 Lowerlimit')
#plt.plot(a, Low1,label='Spin-1 Lowerlimit')
#plt.plot(a, Low2,label='Spin-2 Lowerlimit')
plt.axvline(x=0.5,color='black',linestyle='dashed', linewidth=1.5)
plt.axvline(x=0.94,color='black',linestyle='dashed', linewidth=1.5)
plt.ylabel(r'$\mu_b$ (eV)')
plt.xlabel(r'$a_*$')

ax = plt.gca()
ax.fill_between(a1,Up0[43:],Low0[43:], color='green', interpolate=True,alpha=1,label='Spin-0 ')

ax.fill_between(a[10:],Up0[10:],Low1[10:], color='orange', interpolate=True,alpha=0.5,label='Spin-1')

ax.fill_between(a[25:],Up0[25:],Low2[25:], color='grey', interpolate=True,alpha=0.5,label='Spin-2')

ax.text(0.46, 1.9e-19, "$a_*=0.5$", rotation=90, va='center',fontsize=22)
ax.text(0.9, 1.9e-19, "$a_*=0.94$", rotation=90, va='center',fontsize=22)

plt.yscale('log')

plt.legend(loc=0,prop={'size':25})
plt.show()
pltname = 'final_mu_a'
fig.savefig('Plots_pdf/'+pltname+'.pdf',bbox_inches='tight')
fig.savefig('Plots_png/'+pltname+'.png',bbox_inches='tight')
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
